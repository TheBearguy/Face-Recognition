# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
dataset = pd.read_csv("Obesity Classification.csv")
print("DataSet : %s"%(str(dataset.shape)))
# Out:
# DataSet : (108, 7)

# %%
dataset
# Out:
#       ID  Age  Gender  Height  Weight   BMI          Label
# 0      1   25    Male     175      80  25.3  Normal Weight
# 1      2   30  Female     160      60  22.5  Normal Weight
# 2      3   35    Male     180      90  27.3     Overweight
# 3      4   40  Female     150      50  20.0    Underweight
# 4      5   45    Male     190     100  31.2          Obese
# ..   ...  ...     ...     ...     ...   ...            ...
# 103  106   11    Male     175      10   3.9    Underweight
# 104  107   16  Female     160      10   3.9    Underweight
# 105  108   21    Male     180      15   5.6    Underweight
# 106  109   26  Female     150      15   5.6    Underweight
# 107  110   31    Male     190      20   8.3    Underweight
#
# [108 rows x 7 columns]

# %%
x = dataset.iloc[:,:-1].values
y = dataset.iloc[:,6].values

# %%
x
# Out:
# array([[1, 25, 'Male', 175, 80, 25.3],
#        [2, 30, 'Female', 160, 60, 22.5],
#        [3, 35, 'Male', 180, 90, 27.3],
#        [4, 40, 'Female', 150, 50, 20.0],
#        [5, 45, 'Male', 190, 100, 31.2],
#        [6, 50, 'Female', 140, 40, 16.7],
#        [7, 55, 'Male', 200, 110, 34.2],
#        [8, 60, 'Female', 130, 30, 13.3],
#        [9, 65, 'Male', 210, 120, 37.2],
#        [10, 70, 'Female', 120, 20, 10.0],
#        [11, 18, 'Male', 175, 70, 23.4],
#        [12, 23, 'Female', 160, 50, 20.0],
#        [13, 28, 'Male', 180, 80, 25.3],
#        [14, 33, 'Female', 150, 60, 22.5],
#        [15, 38, 'Male', 190, 90, 27.3],
#        [16, 43, 'Female', 140, 50, 20.0],
#        [17, 48, 'Male', 200, 100, 31.2],
#        [19, 53, 'Female', 130, 40, 16.7],
#        [20, 58, 'Male', 210, 110, 34.2],
#        [21, 63, 'Female', 120, 30, 13.3],
#        [22, 68, 'Male', 175, 80, 25.3],
#        [23, 73, 'Female', 160, 60, 22.5],
#        [24, 78, 'Male', 180, 90, 27.3],
# ...

# %%
y
# Out:
# array(['Normal Weight', 'Normal Weight', 'Overweight', 'Underweight',
#        'Obese', 'Underweight', 'Obese', 'Underweight', 'Obese',
#        'Underweight', 'Normal Weight', 'Underweight', 'Normal Weight',
#        'Normal Weight', 'Overweight', 'Underweight', 'Obese',
#        'Underweight', 'Obese', 'Underweight', 'Normal Weight',
#        'Normal Weight', 'Overweight', 'Underweight', 'Obese',
#        'Underweight', 'Obese', 'Underweight', 'Obese', 'Normal Weight',
#        'Normal Weight', 'Overweight', 'Overweight', 'Overweight', 'Obese',
#        'Overweight', 'Obese', 'Overweight', 'Normal Weight',
#        'Underweight', 'Normal Weight', 'Normal Weight', 'Overweight',
#        'Normal Weight', 'Overweight', 'Overweight', 'Obese', 'Overweight',
#        'Normal Weight', 'Underweight', 'Normal Weight', 'Normal Weight',
#        'Overweight', 'Normal Weight', 'Overweight', 'Overweight', 'Obese',
#        'Overweight', 'Normal Weight', 'Underweight', 'Normal Weight',
# ...

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
# Fit the imputer on x. Make the model fit on the given dataset
imputer = imputer.fit(x[:, 1:6])
x[:, 1:3] = imputer.transform(x[:, 1:6])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 4
#       2 imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
#       3 # Fit the imputer on x
# ----> 4 imputer = imputer.fit(x[:, 1:6])
#       5 x[:, 1:3] = imputer.transform(x[:, 1:6])
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/impute/_base.py:390, in SimpleImputer.fit(self, X, y)
#     381 if self.verbose != "deprecated":
#     382     warnings.warn(
#     383         "The 'verbose' parameter was deprecated in version "
#     384         "1.1 and will be removed in 1.3. A warning will "
#    (...)
#     387         FutureWarning,
#     388     )
# --> 390 X = self._validate_input(X, in_fit=True)
#     392 # default fill_value is 0 for numerical input and "missing_value"
#     393 # otherwise
#     394 if self.fill_value is None:
#
# ...

# %%
x
